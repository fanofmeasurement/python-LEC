# %% [markdown]
# ## 函数中参数的传递

# %% [markdown]
# ### 缺省参数的定义

# %%
def thank_you(name):
    # This function prints a two-line personalized thank you message.
    print("\n你作业做的太棒了, %s!" % name)
    print("我第一次做的时候绝对做不了这么好.")
    
thank_you('萧敬腾')
thank_you('张学友')
thank_you('刘德华')
# Out:
# 你作业做的太棒了, 萧敬腾!
# 我第一次做的时候绝对做不了这么好.
#
# 你作业做的太棒了, 张学友!
# 我第一次做的时候绝对做不了这么好.
#
# 你作业做的太棒了, 刘德华!
# 我第一次做的时候绝对做不了这么好.

# %%
thank_you()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-745d44e51940> in <module>()
# ----> 1 thank_you()
#
# TypeError: thank_you() missing 1 required positional argument: 'name'

# %%
def thank_you(name="同学"):
    # This function prints a two-line personalized thank you message.
    print("\n你作业做的太棒了, %s!" % name)
    print("我第一次做的时候绝对做不了这么好.")
    
thank_you('萧敬腾')
thank_you('张学友')
thank_you('刘德华')
thank_you()
# Out:
# 你作业做的太棒了, 萧敬腾!
# 我第一次做的时候绝对做不了这么好.
#
# 你作业做的太棒了, 张学友!
# 我第一次做的时候绝对做不了这么好.
#
# 你作业做的太棒了, 刘德华!
# 我第一次做的时候绝对做不了这么好.
#
# 你作业做的太棒了, 同学!
# 我第一次做的时候绝对做不了这么好.

# %% [markdown]
# #### 小练习：我最近最喜欢的电影
# 写一个类似的函数，至少调用函数三次，至少有一次不包含参数。

# %% [markdown]
# ### 位置参数
# 传递两个以上参数

# %%
def describe_person(nicheng, sex, city):
    print("昵称: %s" % nicheng)
    print("性别: %s" % sex)
    print("城市: %s\n" % city)

describe_person('elle', '女', '武汉')
describe_person('S.F.Y', '女', '密克罗尼西亚')
describe_person('猪早早', '女', '米兰')
# Out:
# 昵称: elle
# 性别: 女
# 城市: 武汉
#
# 昵称: S.F.Y
# 性别: 女
# 城市: 密克罗尼西亚
#
# 昵称: 猪早早
# 性别: 女
# 城市: 米兰

# %%
def describe_person(nicheng, sex, city):
    print("昵称: %s" % nicheng)
    print("性别: %s" % sex)
    print("城市: %s\n" % city)

describe_person( '武汉','elle', '女')
describe_person( '密克罗尼西亚','S.F.Y', '女')
describe_person( '米兰','猪早早', '女')
# Out:
# 昵称: 武汉
# 性别: elle
# 城市: 女
#
# 昵称: 密克罗尼西亚
# 性别: S.F.Y
# 城市: 女
#
# 昵称: 米兰
# 性别: 猪早早
# 城市: 女

# %% [markdown]
# #### 小练习：炸鸡和啤酒最配
# 写一个类似的函数显示你认为最搭的两种食物，至少调用函数三次。

# %% [markdown]
# ### 关键词参数

# %%
def describe_person(nicheng, sex, city):
    print("昵称: %s" % nicheng)
    print("性别: %s" % sex)
    print("城市: %s\n" % city)

describe_person(city= '武汉',nicheng='elle',sex= '女')
describe_person(city= '密克罗尼西亚',nicheng='S.F.Y', sex='女')
describe_person(city= '米兰',nicheng='猪早早',sex= '女')
# Out:
# 昵称: elle
# 性别: 女
# 城市: 武汉
#
# 昵称: S.F.Y
# 性别: 女
# 城市: 密克罗尼西亚
#
# 昵称: 猪早早
# 性别: 女
# 城市: 米兰

# %% [markdown]
# ### 混合位置和关键词参数

# %%
def describe_person(sex, city, source, nicheng=None,signature=None):    
    print("性别: %s" % sex)
    print("城市: %s" % city)
    print("来源: %s" % source)
    print("昵称: %s" % nicheng)
    print("签名: %s\n" % signature)

describe_person( '女', '武汉','通过群聊添加',nicheng='elle',signature='爱是我们把握最终现实的力量')
describe_person( '女', '密克罗尼西亚','通过分享名片添加',nicheng='S.F.Y')
describe_person( '女', '米兰','通过电话号码添加',signature='不服来战')
# Out:
# 性别: 女
# 城市: 武汉
# 来源: 通过群聊添加
# 昵称: elle
# 签名: 爱是我们把握最终现实的力量
#
# 性别: 女
# 城市: 密克罗尼西亚
# 来源: 通过分享名片添加
# 昵称: S.F.Y
# 签名: None
#
# 性别: 女
# 城市: 米兰
# 来源: 通过电话号码添加
# 昵称: None
# 签名: 不服来战

# %%
def describe_person(sex, city, source, nicheng=None,signature=None):    
    print("性别: %s" % sex)
    print("城市: %s" % city)
    print("来源: %s" % source)
    if nicheng:
        print("昵称: %s" % nicheng)
    if signature:
        print("签名: %s" % signature)
    print("\n")

describe_person( '女', '武汉','通过群聊添加',nicheng='elle',signature='爱是我们把握最终现实的力量')
describe_person( '女', '密克罗尼西亚','通过分享名片添加',nicheng='S.F.Y')
describe_person( '女', '米兰','通过电话号码添加',signature='不服来战')
# Out:
# 性别: 女
# 城市: 武汉
# 来源: 通过群聊添加
# 昵称: elle
# 签名: 爱是我们把握最终现实的力量
#
#
# 性别: 女
# 城市: 密克罗尼西亚
# 来源: 通过分享名片添加
# 昵称: S.F.Y
#
#
# 性别: 女
# 城市: 米兰
# 来源: 通过电话号码添加
# 签名: 不服来战

# %% [markdown]
# #### 小练习：清点一下你的购物车
# 写一个类似的函数显示商品的属性，使用混合参数的方法，至少调用函数三次。

# %% [markdown]
# ### 可变参数

# %% [markdown]
# #### 接受任意长度的序列作为参数
# *args

# %% [markdown]
# + 把第一个值给了参数一
# + 把第二个值给了参数二
# + 把其他的值，作为**元组**，给了参数三

# %%
def example_function(arg_1, arg_2, *arg_3):
    # Let's look at the argument values.
    print('\narg_1:', arg_1)
    print('arg_2:', arg_2)
    print('arg_3:', arg_3)
    
example_function(1, 2)
example_function(1, 2, 3)
example_function(1, 2, 3, 4)
example_function(1, 2, 3, 4, 5)
# Out:
# arg_1: 1
# arg_2: 2
# arg_3: ()
#
# arg_1: 1
# arg_2: 2
# arg_3: (3,)
#
# arg_1: 1
# arg_2: 2
# arg_3: (3, 4)
#
# arg_1: 1
# arg_2: 2
# arg_3: (3, 4, 5)

# %% [markdown]
# 可以循环形式把元组内容逐一显示出来

# %%
def example_function(arg_1, arg_2, *arg_3):
    # Let's look at the argument values.
    print('\narg_1:', arg_1)
    print('arg_2:', arg_2)
    for value in arg_3:
        print('arg_3 value:', value)

example_function(1, 2)
example_function(1, 2, 3)
example_function(1, 2, 3, 4)
example_function(1, 2, 3, 4, 5)
# Out:
# arg_1: 1
# arg_2: 2
#
# arg_1: 1
# arg_2: 2
# arg_3 value: 3
#
# arg_1: 1
# arg_2: 2
# arg_3 value: 3
# arg_3 value: 4
#
# arg_1: 1
# arg_2: 2
# arg_3 value: 3
# arg_3 value: 4
# arg_3 value: 5

# %% [markdown]
# #### 小练习：任意长度的数字相加
# 在上例的基础上，写一个函数jiafa，可以加两个数，也可以加多个数，并且把和打印出来。

# %% [markdown]
# #### 任意数字作为关键词参数
# **kwargs

# %% [markdown]
# + 把第一个值给了参数一
# + 把第二个值给了参数二
# + 把其他的值，作为**字典**，给了参数三

# %%
def example_function(arg_1, arg_2, **kwargs):
    # Let's look at the argument values.
    print('\narg_1:', arg_1)
    print('arg_2:', arg_2)
    print('arg_3:', kwargs)
    
example_function('a', 'b')
example_function('a', 'b', value_3='c')
example_function('a', 'b', value_3='c', value_4='d')
example_function('a', 'b', value_3='c', value_4='d', value_5='e')
# Out:
# arg_1: a
# arg_2: b
# arg_3: {}
#
# arg_1: a
# arg_2: b
# arg_3: {'value_3': 'c'}
#
# arg_1: a
# arg_2: b
# arg_3: {'value_3': 'c', 'value_4': 'd'}
#
# arg_1: a
# arg_2: b
# arg_3: {'value_3': 'c', 'value_4': 'd', 'value_5': 'e'}

# %% [markdown]
# 我们也可以通过循环的形式把kwargs里的内容逐一打印出来

# %%
def example_function(arg_1, arg_2, **kwargs):
    # Let's look at the argument values.
    print('\narg_1:', arg_1)
    print('arg_2:', arg_2)
    for key, value in kwargs.items():
        print('arg_3 value:', value)
    
example_function('a', 'b')
example_function('a', 'b', value_3='c')
example_function('a', 'b', value_3='c', value_4='d')
example_function('a', 'b', value_3='c', value_4='d', value_5='e')
# Out:
# arg_1: a
# arg_2: b
#
# arg_1: a
# arg_2: b
# arg_3 value: c
#
# arg_1: a
# arg_2: b
# arg_3 value: c
# arg_3 value: d
#
# arg_1: a
# arg_2: b
# arg_3 value: c
# arg_3 value: d
# arg_3 value: e

# %% [markdown]
# 我们可以把混合位置和关键词参数的方法用kwargs重写一次

# %%
def describe_person(sex, city, source, **kwargs):    
    print("性别: %s" % sex)
    print("城市: %s" % city)
    print("来源: %s" % source)
    for key in kwargs:
        print("%s: %s" % (key.title(), kwargs[key]))
    print("\n")

describe_person( '女', '武汉','通过群聊添加',nicheng='elle',signature='爱是我们把握最终现实的力量')
describe_person( '女', '密克罗尼西亚','通过分享名片添加',nicheng='S.F.Y')
describe_person( '女', '米兰','通过电话号码添加',signature='不服来战')
# Out:
# 性别: 女
# 城市: 武汉
# 来源: 通过群聊添加
# Nicheng: elle
# Signature: 爱是我们把握最终现实的力量
#
#
# 性别: 女
# 城市: 密克罗尼西亚
# 来源: 通过分享名片添加
# Nicheng: S.F.Y
#
#
# 性别: 女
# 城市: 米兰
# 来源: 通过电话号码添加
# Signature: 不服来战

# %% [markdown]
# #### 小练习：清点一下你的购物车
# 把刚才用混合方法写的清点购物车用kwargs再写一次。
