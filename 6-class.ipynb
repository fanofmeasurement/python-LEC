# %% [markdown]
# ## python中的类

# %% [markdown]
# ### 类是什么
# 介绍类之前，先介绍一个类的实例

# %% [markdown]
# ![](http://i4.fuimg.com/611786/60bdfadccfc93ac5.jpg)

# %% [markdown]
# 对马里奥来说，我们可以描述他的诸多特征：
# + 大鼻子
# + 红帽子
# + 蓝色背带裤
# + 红色衬衣
# + 还留着胡子

# %% [markdown]
# ![](http://i4.fuimg.com/611786/c4071b1e8f23165e.jpg)

# %% [markdown]
# 对马里奥来说，不仅仅是一个静止的形象，还是一个活蹦乱跳的游戏人物：
# + 跑
# + 跳、三级跳、远跳
# + 下蹲
# + 翻滚
# + 空中小幅移动
# + 后空翻、侧空翻
# + 扔帽子
# + 游泳
# + ......

# %% [markdown]
# ![](http://i4.fuimg.com/611786/366e2653983d3b15.jpg)

# %% [markdown]
# ![](http://i4.fuimg.com/611786/cda28515c3520f92.gif)

# %% [markdown]
# ![](http://i4.fuimg.com/611786/9afa2e58b62149a0.gif)

# %% [markdown]
# ![](http://i2.tiimg.com/611786/61a74b5b1117cf31.gif)

# %% [markdown]
# ### 总结下，马里奥：
# + 有一些特征
# + 有一些“预装”好的操作，或者叫“主角光环”、“人设”等等
# + “血”掉光了后，重新来过，又有一个新的马里奥

# %% [markdown]
# ### 在python的类里，称之为：
#
# + 属性(其实就是变量)
# + 方法（很像函数）
# + 类和实例

# %% [markdown]
# ### 类的概念概括性很强：
# + 贫困
#     + 阿马蒂亚.森：“可行能力”的贫困
#     + 收入是不是贫困的特征呢？
#     + 贫困的特征应该是指向获取美好生活的行动的
# + 依恋类型
#     + 一种人格分类
#     + 不同的类都有自己的特征和基本稳定的一些恋爱过程中表现(方法、操作等)
#     + 你遇到的每个人都是类里的一些实例

# %% [markdown]
# ### 类里设定属性的值

# %% [markdown]
# #### 例子：依恋类型里的倾注型

# %%
class preoccupied():
    def __init__(self):
        self.zhui = True
        self.fenshou = False
        self.manyi = False
        self.jiji = False

# %%
boyfriend = preoccupied
print(boyfriend)
# Out:
# <class '__main__.preoccupied'>

# %% [markdown]
# #### 倾注型的特点：
# + “宁可错杀一千也不放过一个”
# + 天天吵闹要分手，却迟迟不走
# + 无论你做什么，都对你不满意，嫌你对TA不好
# + 甚少做出有利于关心的行为

# %% [markdown]
# #### 《冰雨》
#
# 我是在等待一个女孩
# 还是在等待沉沦苦海
# 一段情默默灌溉
# 没有人去管花谢花开
# 无法肯定的爱 左右摇摆
# 只好把心酸往深心里塞
# ......

# %%
class preoccupied():
    def __init__(self):
        self.zhui = True
        self.fenshou = False
        self.manyi = False
        self.jiji = False

# %%
mounan = preoccupied()
print(mounan.zhui)
# Out:
# True

# %% [markdown]
# #### 传递参数

# %%
class preoccupied():
    def __init__(self):
        self.zhui = True
        self.fenshou = False
        self.manyi = False
        self.jiji = False
    
    def xiangqin(self,girl):
        if girl == 'beautiful' :
            self.zhui = self.zhui
        else :
            self.zhui = self.zhui or True 
            
    def chaojia(self,chengdu,cishu):
        if chengdu > 5 or cishu>1000:
            self.fenshou = True
        else :
            self.fenshou = self.fenshou

# %%
mounan = preoccupied()
print(mounan.zhui)

#### 抓住机会
mounan.xiangqin(girl = "ugly")
print(mounan.zhui)

#### 一般的吵架不分手
mounan.chaojia(chengdu = 4,cishu = 20)
print(mounan.fenshou)

#### 超的少了不分手
mounan.chaojia(chengdu = 3,cishu = 1001)
print(mounan.fenshou)
# Out:
# True
# True
# False
# True

# %% [markdown]
# ### 类里不设定，生成实例时赋予属性值

# %% [markdown]
# #### 上例再一般化一些，我们认为可以从追、分手、满意、积极这几个方面来看人在恋爱中表现的话。
# + 不预先赋值
# + 生成实例的时候再赋值
# + 方法保持不变

# %%
class preoccupied(object):
    def __init__(self,x1,x2,x3,x4): ## 需要定义传递的值
        self.zhui = x1
        self.fenshou = x2
        self.manyi = x3
        self.jiji = x4
    
    def xiangqin(self,girl):
        if girl == 'beautiful' :
            self.zhui = self.zhui
        else :
            self.zhui = self.zhui or True 
            
    def chaojia(self,chengdu,cishu):
        if chengdu > 5 or cishu>1000:
            self.fenshou = True
        else :
            self.fenshou = self.fenshou

# %%
mounan = preoccupied(True, False, False, False)

#### 抓住机会
mounan.xiangqin(girl = "ugly")
print(mounan.zhui)

#### 一般的吵架不分手
mounan.chaojia(chengdu = 4,cishu = 20)
print(mounan.fenshou)

#### 超的少了不分手
mounan.chaojia(chengdu = 3,cishu = 1001)
print(mounan.fenshou)
# Out:
# True
# False
# True

# %% [markdown]
# #### 创建多个实例

# %%
class preoccupied(object):
    def __init__(self,x1,x2,x3,x4): ## 需要定义传递的值
        self.zhui = x1
        self.fenshou = x2
        self.manyi = x3
        self.jiji = x4
    
    def xiangqin(self,girl):
        if girl == 'beautiful' :
            self.zhui = self.zhui
        else :
            self.zhui = self.zhui or True 
            
    def chaojia(self,chengdu,cishu):
        if chengdu > 5 or cishu>1000:
            self.fenshou = True
        else :
            self.fenshou = self.fenshou 

yixieren = []

yixieren.append(preoccupied(False, False, False, False))
yixieren.append(preoccupied(True, False, False, False))
yixieren.append(preoccupied(True, False, False, True))

for index, man in enumerate(yixieren):
    print(mounan.fenshou)
# Out:
# True
# True
# True

# %% [markdown]
# #### 改变方法

# %%
class preoccupied(object):
    def __init__(self,x1,x2,x3,x4): ## 需要定义传递的值
        self.zhui = x1
        self.fenshou = x2
        self.manyi = x3
        self.jiji = x4
    
    def xiangqin(self,girl):
        if girl == 'beautiful' : # 好看才追
            self.zhui = True
        else :
            self.zhui = self.zhui # 不好看取决于我的人格特质
            
    def chaojia(self,chengdu,cishu):
        if chengdu > 5 or cishu>1000:
            self.fenshou = True
        else :
            self.fenshou = self.fenshou

# %%
mounan = preoccupied(False, False, False, False)

#### 抓住机会
mounan.xiangqin(girl = "ugly")
print(mounan.zhui)

#### 一般的吵架不分手
mounan.chaojia(chengdu = 4,cishu = 20)
print(mounan.fenshou)

#### 超的少了不分手
mounan.chaojia(chengdu = 3,cishu = 1001)
print(mounan.fenshou)
# Out:
# False

# %% [markdown]
# #### 练习：学生信息
# + 创建一个类，包含姓名、分数、睡眠时间三个属性
# + 包含一个胖瘦的预测，如果分数>90，且睡眠时间少于6小时，输出“BMI可能偏大”，否则输出“体重正常”
# + 为使得标准（90分、6小时）可以调整，应设为输入的参数

# %%
class Student(object):
 
  def __init__(self, name, score):
    self.name = name
    self.score = score
  
  def get_grade(self,c1,c2):
    if self.score >= c1:
      return 'A'
    elif self.score >= c2:
      return 'B'
    else:
      return 'C'

# %%
stu = Student('韩梅梅', 89)
stu.name
# Out:
# '韩梅梅'

# %%
stu.get_grade(90,60)
# Out:
# 'B'

# %% [markdown]
# ### 类的继承

# %% [markdown]
# #### 马里奥的历史很悠久
# + 有很早期的街机
# + 红白机
# + .......
# + switch
#
# 但是他的一些基本特征和操作，一直保留下来，后期的马里奥都继承了之前版本的经典部分

# %% [markdown]
# #### 定义一个火箭

# %%
from math import sqrt

class Rocket():
    # Rocket simulates a rocket ship for a game,
    #  or a physics simulation.
    
    def __init__(self, x=0, y=0):
        # Each rocket has an (x,y) position.
        self.x = x
        self.y = y
        
    def move_rocket(self, x_increment=0, y_increment=1):
        # Move the rocket according to the paremeters given.
        #  Default behavior is to move the rocket up one unit.
        self.x += x_increment
        self.y += y_increment
        
    def get_distance(self, other_rocket):
        # Calculates the distance from this rocket to another rocket,
        #  and returns that value.
        distance = sqrt((self.x-other_rocket.x)**2+(self.y-other_rocket.y)**2)
        return distance
    
rocket_0 = Rocket()
rocket_1 = Rocket(10,5)

# Show the distance between them.
distance = rocket_0.get_distance(rocket_1)
print("The rockets are %f units apart." % distance)
# Out:
# The rockets are 11.180340 units apart.

# %% [markdown]
# #### 航天飞机继承了火箭

# %%
class Shuttle(Rocket):
    # Shuttle simulates a space shuttle, which is really
    #  just a reusable rocket.
    
    def __init__(self, x=0, y=0, flights_completed=0):
        super().__init__(x, y)                      ## 通过super函数声明继承了父类的属性
        self.flights_completed = flights_completed
        
shuttle = Shuttle(10,0,3)
print(shuttle.flights_completed)



rocket_0 = Shuttle()
rocket_1 = Shuttle(10,5,3)

# Show the distance between them.
distance = rocket_0.get_distance(rocket_1)
print("The shuttle are %f units apart." % distance)
# Out:
# 3
# The shuttle are 11.180340 units apart.
